# %% [markdown]
# # Example: Create a cell type reference gene expression file from a scRNA-seq atlas with cell type annotation.
# - Using Human colon cancer atlas as example.
# - Data downloaded from GSE178341, with h5 and cell type labels.
# ## We already know cutoffs for good quality so Step0 can be skipped:
# - MIN_GENES = 100
# - MIN_COUNTS = 100
# - MIN_CELLS = 3
# - MAX_MITO_PERCENT=27.77

# %%
import os
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import sys
# add STHD path
sys.path.append('../')

# (pip version to be published)
# pip install STHD

# %% [markdown]
# # Step 0 (Optional): Find Good QC cutoffs
# ## Load scRNA reference

# %%
crc_dir = '../testdata/crc_scrna/'
adata = sc.read_10x_h5('../testdata/crc_scrna/GSE178341_crc10x_full_c295v4_submit.h5')
# Out:
# /hpc/group/yizhanglab/yiz/venv/stvit-cpu/lib64/python3.9/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /hpc/group/yizhanglab/yiz/venv/stvit-cpu/lib64/python3.9/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %% [markdown]
# ## Load cell type names and add to adata

# %%
def load_global_celltype(crc_dir):
    '''
    For colon cancer atlas
    '''
    cell_type_tsne_type_file = 'crc10x_tSNE_cl_global.tsv'
    tmp = pd.read_table( os.path.join(crc_dir, cell_type_tsne_type_file), skiprows=1, index_col = 0) # same cell type and number
    return(tmp)

celltypes = load_global_celltype(crc_dir)
# qc
celltypes = celltypes.loc[ celltypes.index.intersection(adata.obs.index) ]
celltypes_group1 = celltypes.groupby('group.1').count().index.tolist()
celltypes_group = celltypes.groupby('group').count().index.tolist()

adata.obsm['X_tsne'] = celltypes[['numeric','numeric.1']].loc[adata.obs.index].values
adata.obs['group']=celltypes['group'].loc[adata.obs.index].values
adata.obs['group.1']=celltypes['group.1'].loc[adata.obs.index].values

# %% [markdown]
# ## Optional plotting

# %%
sc.pl.tsne(adata,color='group.1')
sc.pl.tsne(adata,color='group')

# %% [markdown]
# ## Finding QC criterion: Optional for first time QC: QC and mitochondrial control. can skip if you know the QC cutoffs.

# %%
MIN_GENES = 100
MIN_COUNTS = 100
MIN_CELLS = 3
random_state = 42

# %%
adata.var_names_make_unique()
adata.var['mt'] = adata.var_names.str.startswith('MT-') | adata.var_names.str.startswith('mt-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
sc.pl.violin(
    adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)
sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %%
import matplotlib.pyplot as plt
sc.pl.tsne(adata,color='pct_counts_mt')
#plt.savefig('../analysis/figure/crc95_ref_qc_pct_counts_mt.pdf', dpi=300)

# %%
import seaborn as sns
sns.displot(adata.obs['pct_counts_mt'].values)
plt.axvline(27.7, color='pink')
plt.xlabel('pct_counts_mt')

# %%
# either

MAX_MITO_PERCENT = adata.obs['pct_counts_mt'].mean() + adata.obs['pct_counts_mt'].std()
print(f'Mito cutoff option: {MAX_MITO_PERCENT}')
# Out:
# Mito cutoff option: 27.771158613939527

# %%
sc.pp.filter_cells(adata, min_genes = MIN_GENES)  
sc.pp.filter_cells(adata, min_counts = MIN_COUNTS )   
sc.pp.filter_genes(adata, min_cells = MIN_CELLS)

print('pre mt filtering ', adata.shape[0])
adata = adata[adata.obs.pct_counts_mt < MAX_MITO_PERCENT , :]
print('post mt filtering ', adata.shape[0])
# Out:
# pre mt filtering  370115
# post mt filtering  303358

# %% [markdown]
# # Step 1: Read in the reference scRNA and QC

# %%
import os
import scanpy as sc
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
crc_dir = '../testdata/crc_scrna/'
adata = sc.read_10x_h5('../testdata/crc_scrna/GSE178341_crc10x_full_c295v4_submit.h5')
# Out:
# /hpc/group/yizhanglab/yiz/venv/stvit-cpu/lib64/python3.9/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /hpc/group/yizhanglab/yiz/venv/stvit-cpu/lib64/python3.9/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %% [markdown]
# ## Get cell type and load to raw data

# %%
def load_global_celltype(crc_dir):
    '''
    For colon cancer atlas
    '''
    cell_type_tsne_type_file = 'crc10x_tSNE_cl_global.tsv'
    tmp = pd.read_table( os.path.join(crc_dir, cell_type_tsne_type_file), skiprows=1, index_col = 0) # same cell type and number
    return(tmp)

celltypes = load_global_celltype(crc_dir)
# qc
celltypes = celltypes.loc[ celltypes.index.intersection(adata.obs.index) ]
celltypes_group1 = celltypes.groupby('group.1').count().index.tolist()
celltypes_group = celltypes.groupby('group').count().index.tolist()

# %%
adata.obsm['X_tsne'] = celltypes[['numeric','numeric.1']].loc[adata.obs.index].values
adata.obs['group']=celltypes['group'].loc[adata.obs.index].values
adata.obs['group.1']=celltypes['group.1'].loc[adata.obs.index].values

# %% [markdown]
# ## KEEP the raw counts

# %%
adata.var_names_make_unique()
if('counts') not in adata.layers.keys():
    adata.layers["counts"] = adata.X.copy()
# Out:
# /hpc/group/yizhanglab/yiz/venv/stvit-cpu/lib64/python3.9/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(

# %% [markdown]
# ### QC and Mitochondrial control: we use the thresholds from observations

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-') | adata.var_names.str.startswith('mt-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

MIN_GENES = 100
MIN_COUNTS = 100
MIN_CELLS = 3
random_state = 42

sc.pp.filter_cells(adata, min_genes = MIN_GENES)  
sc.pp.filter_cells(adata, min_counts = MIN_COUNTS )   
sc.pp.filter_genes(adata, min_cells = MIN_CELLS)

MAX_MITO_PERCENT=27.77

print('pre mt filtering ', adata.shape[0])
adata = adata[adata.obs.pct_counts_mt < MAX_MITO_PERCENT , :]
print('post mt filtering ', adata.shape[0])
# Out:
# pre mt filtering  370115
# post mt filtering  303350

# %%
adata.obs['n_counts'].values.mean()
# Out:
# 12301.415025548047

# %%
#sc.pl.tsne(adata,color='group', save='crc98_ref_celltype_umap.pdf')

# %% [markdown]
# # Step 2: Convert gene counts into normalized gene expression per-cell type for gene selection
# - proportion of genes sum to 1 for a cell

# %%
import STHD.refscrna

# %%
from STHD.refscrna import gene_lambda_by_ct
genemeanpd, genemeanpdfc = gene_lambda_by_ct(adata, ctcol = 'group')
# Out:
# [Log] 300 cells for cell type cM03 (DC1)
# dimension of cell by gene count (300, 31873)
# [Log] 11362 cells for cell type cB2 (B GC-like)
# dimension of cell by gene count (11362, 31873)
# [Log] 722 cells for cell type cS05 (Endo venous)
# dimension of cell by gene count (722, 31873)
# [Log] 15824 cells for cell type cP2 (Plasma IgG)
# dimension of cell by gene count (15824, 31873)
# [Log] 485 cells for cell type cTNI12 (CD8+ IL7R+)
# dimension of cell by gene count (485, 31873)
# [Log] 386 cells for cell type cS10 (Endo tip cells)
# dimension of cell by gene count (386, 31873)
# [Log] 94 cells for cell type cM08 (AS-DC)
# dimension of cell by gene count (94, 31873)
# [Log] 1299 cells for cell type Tumor cE05 (Enterocyte 2)
# dimension of cell by gene count (1299, 31873)
# [Log] 518 cells for cell type cS21 (Fibro stem cell niche)
# dimension of cell by gene count (518, 31873)
# [Log] 788 cells for cell type cTNI22 (cTNI22)
# dimension of cell by gene count (788, 31873)
# [Log] 4516 cells for cell type cTNI11 (CD8+GZMK+)
# dimension of cell by gene count (4516, 31873)
# [Log] 4270 cells for cell type cTNI02 (CD4+ IL7R+SELL+)
# dimension of cell by gene count (4270, 31873)
# [Log] 1234 cells for cell type cTNI23 (NK CD16A+)
# dimension of cell by gene count (1234, 31873)
# [Log] 1247 cells for cell type cS13 (Endo venous-like)
# dimension of cell by gene count (1247, 31873)
# [Log] 13765 cells for cell type cM01 (Monocyte)
# dimension of cell by gene count (13765, 31873)
# [Log] 349 cells for cell type cS19 (Pericyte)
# dimension of cell by gene count (349, 31873)
# [Log] 95 cells for cell type cE11 (Enteroendocrine)
# dimension of cell by gene count (95, 31873)
# [Log] 282 cells for cell type cS06 (Endo lymphatic)
# dimension of cell by gene count (282, 31873)
# [Log] 337 cells for cell type cS17 (Pericyte)
# dimension of cell by gene count (337, 31873)
# [Log] 6782 cells for cell type Tumor cE02 (Stem/TA-like/Immature Goblet)
# dimension of cell by gene count (6782, 31873)
# [Log] 441 cells for cell type cS08 (Endo arterial-like)
# dimension of cell by gene count (441, 31873)
# [Log] 1876 cells for cell type cTNI03 (CD4+ IL7R+HSP+)
# dimension of cell by gene count (1876, 31873)
# [Log] 1066 cells for cell type cM05 (DC2 C1Q+)
# dimension of cell by gene count (1066, 31873)
# [Log] 3917 cells for cell type cE05 (Enterocyte 2)
# dimension of cell by gene count (3917, 31873)
# [Log] 1775 cells for cell type cTNI09 (CD4+ Treg prolif)
# dimension of cell by gene count (1775, 31873)
# [Log] 437 cells for cell type cS01 (Endo arterial)
# dimension of cell by gene count (437, 31873)
# [Log] 673 cells for cell type cS27 (CXCL14+ CAF)
# dimension of cell by gene count (673, 31873)
# [Log] 5421 cells for cell type cTNI17 (gd-like T)
# dimension of cell by gene count (5421, 31873)
# [Log] 1090 cells for cell type cM04 (DC2)
# dimension of cell by gene count (1090, 31873)
# [Log] 1008 cells for cell type Tumor cE10 (Tuft)
# dimension of cell by gene count (1008, 31873)
# [Log] 412 cells for cell type cS03 (Endo capillary)
# dimension of cell by gene count (412, 31873)
# [Log] 9530 cells for cell type cTNI08 (CD4+ Treg)
# dimension of cell by gene count (9530, 31873)
# [Log] 254 cells for cell type Tumor cE11 (Enteroendocrine)
# dimension of cell by gene count (254, 31873)
# [Log] 194 cells for cell type cS04 (Endo)
# dimension of cell by gene count (194, 31873)
# [Log] 660 cells for cell type cTNI21 (PLZF+ T prolif)
# dimension of cell by gene count (660, 31873)
# [Log] 216 cells for cell type cS26 (Myofibro)
# dimension of cell by gene count (216, 31873)
# [Log] 1871 cells for cell type cM10 (Granulocyte)
# dimension of cell by gene count (1871, 31873)
# [Log] 314 cells for cell type cE07 (Goblet/Enterocyte)
# dimension of cell by gene count (314, 31873)
# [Log] 38 cells for cell type cS14 (Endo)
# dimension of cell by gene count (38, 31873)
# [Log] 6182 cells for cell type cB3 (B CD40+ GC-like)
# dimension of cell by gene count (6182, 31873)
# [Log] 44 cells for cell type cS20 (Pericyte prolif)
# dimension of cell by gene count (44, 31873)
# [Log] 797 cells for cell type cTNI26 (ILC3)
# dimension of cell by gene count (797, 31873)
# [Log] 14 cells for cell type Tumor cE07 (Goblet/Enterocyte)
# dimension of cell by gene count (14, 31873)
# [Log] 6330 cells for cell type cTNI14 (CD8+ CXCL13+)
# dimension of cell by gene count (6330, 31873)
# [Log] 2920 cells for cell type Tumor cE06 (Immature Goblet)
# dimension of cell by gene count (2920, 31873)
# [Log] 217 cells for cell type cS23 (Fibro BMP-producing)
# dimension of cell by gene count (217, 31873)
# [Log] 1999 cells for cell type cTNI13 (CD8+ T IL17+)
# dimension of cell by gene count (1999, 31873)
# [Log] 194 cells for cell type cS11 (Endo proif)
# dimension of cell by gene count (194, 31873)
# [Log] 2095 cells for cell type cTNI07 (CD4+ CXCL13+)
# dimension of cell by gene count (2095, 31873)
# [Log] 439 cells for cell type cS25 (Fibro CCL8+)
# dimension of cell by gene count (439, 31873)
# [Log] 19434 cells for cell type cM02 (Macrophage-like)
# dimension of cell by gene count (19434, 31873)
# [Log] 93 cells for cell type cS07 (Endo capillary-like)
# dimension of cell by gene count (93, 31873)
# [Log] 361 cells for cell type cS29 (MMP3+ CAF)
# dimension of cell by gene count (361, 31873)
# [Log] 181 cells for cell type cS16 (Pericyte)
# dimension of cell by gene count (181, 31873)
# [Log] 1551 cells for cell type cM09 (mregDC)
# dimension of cell by gene count (1551, 31873)
# [Log] 497 cells for cell type cM06 (DC IL22RA2)
# dimension of cell by gene count (497, 31873)
# [Log] 2222 cells for cell type cE08 (Goblet)
# dimension of cell by gene count (2222, 31873)
# [Log] 717 cells for cell type cS09 (Endo)
# dimension of cell by gene count (717, 31873)
# [Log] 223 cells for cell type cS18 (Pericyte)
# dimension of cell by gene count (223, 31873)
# [Log] 2885 cells for cell type cTNI01 (CD4+ IL7R+)
# dimension of cell by gene count (2885, 31873)
# [Log] 639 cells for cell type cS28 (GREM1+ CAF)
# dimension of cell by gene count (639, 31873)
# [Log] 228 cells for cell type cS30 (CAF CCL8 Fibro-like)
# dimension of cell by gene count (228, 31873)
# [Log] 2255 cells for cell type cTNI16 (CD8+ CXCL13+ prolif)
# dimension of cell by gene count (2255, 31873)
# [Log] 20107 cells for cell type cP1 (Plasma IgA)
# dimension of cell by gene count (20107, 31873)
# [Log] 29726 cells for cell type Tumor cE03 (Stem/TA-like prolif)
# dimension of cell by gene count (29726, 31873)
# [Log] 5966 cells for cell type cTNI04 (CD4+ IL7R+CCL5+)
# dimension of cell by gene count (5966, 31873)
# [Log] 2832 cells for cell type cE06 (Immature Goblet)
# dimension of cell by gene count (2832, 31873)
# [Log] 1200 cells for cell type cS02 (Endo capillary)
# dimension of cell by gene count (1200, 31873)
# [Log] 383 cells for cell type cS24 (Fibro BMP-producing)
# dimension of cell by gene count (383, 31873)
# [Log] 473 cells for cell type Tumor cE08 (Goblet)
# dimension of cell by gene count (473, 31873)
# [Log] 4141 cells for cell type cE09 (Best4)
# dimension of cell by gene count (4141, 31873)
# [Log] 840 cells for cell type cM07 (pDC)
# dimension of cell by gene count (840, 31873)
# [Log] 1477 cells for cell type cTNI06 (CD4+ TFH)
# dimension of cell by gene count (1477, 31873)
# [Log] 2803 cells for cell type cTNI05 (CD4+ IL17+)
# dimension of cell by gene count (2803, 31873)
# [Log] 3325 cells for cell type cE03 (Stem/TA-like prolif)
# dimension of cell by gene count (3325, 31873)
# [Log] 457 cells for cell type cS31 (CAF stem niche Fibro-like)
# dimension of cell by gene count (457, 31873)
# [Log] 627 cells for cell type cS12 (Endo)
# dimension of cell by gene count (627, 31873)
# [Log] 3671 cells for cell type cMA01 (Mast)
# dimension of cell by gene count (3671, 31873)
# [Log] 254 cells for cell type cS33 (Schwann)
# dimension of cell by gene count (254, 31873)
# [Log] 1117 cells for cell type cTNI24 (NK GZMK+)
# dimension of cell by gene count (1117, 31873)
# [Log] 643 cells for cell type cTNI25 (NK XCL1+)
# dimension of cell by gene count (643, 31873)
# [Log] 2682 cells for cell type cTNI10 (CD8+ IL7R+)
# dimension of cell by gene count (2682, 31873)
# [Log] 936 cells for cell type cE10 (Tuft)
# dimension of cell by gene count (936, 31873)
# [Log] 252 cells for cell type cS15 (Pericyte)
# dimension of cell by gene count (252, 31873)
# [Log] 2708 cells for cell type cE02 (Stem/TA-like/Immature Goblet)
# dimension of cell by gene count (2708, 31873)
# [Log] 800 cells for cell type cS32 (Smooth Muscle)
# dimension of cell by gene count (800, 31873)
# [Log] 369 cells for cell type cTNI19 (gd-like T prolif)
# dimension of cell by gene count (369, 31873)
# [Log] 203 cells for cell type Tumor cE09 (Best4)
# dimension of cell by gene count (203, 31873)
# [Log] 688 cells for cell type cS22 (Fibro stem cell niche)
# dimension of cell by gene count (688, 31873)
# [Log] 3920 cells for cell type cTNI20 (PLZF+ T)
# dimension of cell by gene count (3920, 31873)
# [Log] 36490 cells for cell type Tumor cE01 (Stem/TA-like)
# dimension of cell by gene count (36490, 31873)
# [Log] 3878 cells for cell type cTNI15 (CD8+ CXCL13+ HSP+)
# dimension of cell by gene count (3878, 31873)
# [Log] 960 cells for cell type Tumor cE04 (Enterocyte 1)
# dimension of cell by gene count (960, 31873)
# [Log] 2003 cells for cell type cE04 (Enterocyte 1)
# dimension of cell by gene count (2003, 31873)
# [Log] 3178 cells for cell type cTNI18 (gd-like T PDCD1+)
# dimension of cell by gene count (3178, 31873)
# [Log] 6939 cells for cell type cB1 (B IGD+IgM+)
# dimension of cell by gene count (6939, 31873)
# [Log] 7886 cells for cell type cE01 (Stem/TA-like)
# dimension of cell by gene count (7886, 31873)
# [Log] 1051 cells for cell type cP3 (Plasma IgG prolif)
# dimension of cell by gene count (1051, 31873)

# %% [markdown]
# # Step 3: Select some cell type-informative genes.

# %% [markdown]
# - Min gene lambda 0.000125 , logFC 0.5.
# - This is example cutoff refers to RCTD STYLE: "Using the estimated cell type expression profiles 𝜇ˆ𝑘,𝑗, we select differentially expressed genes that will be informative when estimating cell type proportions. For each cell type in the scRNA-seq reference, we select genes with minimum average expression above .0625 counts per 500 and at least 0.5 log-fold-change compared to the average expression across all cell types. "

# %%
from STHD.refscrna import select_ct_informative_genes_basic
genemeanpd_filtered = select_ct_informative_genes_basic(genemeanpd, genemeanpdfc, exprcut = 0.000125, fccut = 2**0.5)
# Out:
# 31734 genes after removing MT- and Ribo
# 4618 genes after further removing RCTD threshold gene expression 0.0125
# 4618 genes after further removing RCTD logfc log2 0.5
# (4618, 98)

# %%
# check a few gene markers to see whether they are in.
colon_epithelial_marker = ['LEFTY1','EPHB3','LGR5','ALDH1B1','CDCA7','OLFM4','STMN1','HMGB2','MKI67','CLCA4','AQP8','TMIGD1','GUCA2B','SULT1A2','SLC26A3','SLC26A2','CA1',
           'SPINK1','CLCA1','ITLN1','LRRC26','RETNLB','SPINK4','FCGBP','MUC2','ZG16','BCAS1','ENTPD8','MUC1','TFF1','S100P','NOTCH2NL','OTOP3','REN','BEST4','OTOP2','CA7',
          'AZGP1','HCK','LRMP','SH2D6','HPGDS','PTGS1','CHGA','CRYBA2','SCGN','PYY','SCT','INSL5'] 
','.join([t for t in colon_epithelial_marker  if t in genemeanpd_filtered.index])
# Out:
# 'LEFTY1,ALDH1B1,CDCA7,OLFM4,STMN1,HMGB2,MKI67,CLCA4,AQP8,TMIGD1,GUCA2B,SULT1A2,SLC26A3,SLC26A2,CA1,SPINK1,CLCA1,ITLN1,LRRC26,RETNLB,SPINK4,FCGBP,MUC2,ZG16,BCAS1,ENTPD8,MUC1,TFF1,S100P,NOTCH2NL,BEST4,OTOP2,CA7,AZGP1,HCK,LRMP,SH2D6,HPGDS,PTGS1,CHGA,CRYBA2,SCGN,PYY,SCT,INSL5'

# %% [markdown]
# ## Now, Re-calculate the gene labmdas for the selected celltype-informative genes

# %%
adata_markergs = adata[:, genemeanpd_filtered.index]
genemeanpd_markergs, genemeanpdfc_markergs = gene_lambda_by_ct(adata_markergs, ctcol = 'group')
# Out:
# [Log] 300 cells for cell type cM03 (DC1)
# dimension of cell by gene count (300, 4618)
# [Log] 11362 cells for cell type cB2 (B GC-like)
# dimension of cell by gene count (11362, 4618)
# [Log] 722 cells for cell type cS05 (Endo venous)
# dimension of cell by gene count (722, 4618)
# [Log] 15824 cells for cell type cP2 (Plasma IgG)
# dimension of cell by gene count (15824, 4618)
# [Log] 485 cells for cell type cTNI12 (CD8+ IL7R+)
# dimension of cell by gene count (485, 4618)
# [Log] 386 cells for cell type cS10 (Endo tip cells)
# dimension of cell by gene count (386, 4618)
# [Log] 94 cells for cell type cM08 (AS-DC)
# dimension of cell by gene count (94, 4618)
# [Log] 1299 cells for cell type Tumor cE05 (Enterocyte 2)
# dimension of cell by gene count (1299, 4618)
# [Log] 518 cells for cell type cS21 (Fibro stem cell niche)
# dimension of cell by gene count (518, 4618)
# [Log] 788 cells for cell type cTNI22 (cTNI22)
# dimension of cell by gene count (788, 4618)
# [Log] 4516 cells for cell type cTNI11 (CD8+GZMK+)
# dimension of cell by gene count (4516, 4618)
# [Log] 4270 cells for cell type cTNI02 (CD4+ IL7R+SELL+)
# dimension of cell by gene count (4270, 4618)
# [Log] 1234 cells for cell type cTNI23 (NK CD16A+)
# dimension of cell by gene count (1234, 4618)
# [Log] 1247 cells for cell type cS13 (Endo venous-like)
# dimension of cell by gene count (1247, 4618)
# [Log] 13765 cells for cell type cM01 (Monocyte)
# dimension of cell by gene count (13765, 4618)
# [Log] 349 cells for cell type cS19 (Pericyte)
# dimension of cell by gene count (349, 4618)
# [Log] 95 cells for cell type cE11 (Enteroendocrine)
# dimension of cell by gene count (95, 4618)
# [Log] 282 cells for cell type cS06 (Endo lymphatic)
# dimension of cell by gene count (282, 4618)
# [Log] 337 cells for cell type cS17 (Pericyte)
# dimension of cell by gene count (337, 4618)
# [Log] 6782 cells for cell type Tumor cE02 (Stem/TA-like/Immature Goblet)
# dimension of cell by gene count (6782, 4618)
# [Log] 441 cells for cell type cS08 (Endo arterial-like)
# dimension of cell by gene count (441, 4618)
# [Log] 1876 cells for cell type cTNI03 (CD4+ IL7R+HSP+)
# dimension of cell by gene count (1876, 4618)
# [Log] 1066 cells for cell type cM05 (DC2 C1Q+)
# dimension of cell by gene count (1066, 4618)
# [Log] 3917 cells for cell type cE05 (Enterocyte 2)
# dimension of cell by gene count (3917, 4618)
# [Log] 1775 cells for cell type cTNI09 (CD4+ Treg prolif)
# dimension of cell by gene count (1775, 4618)
# [Log] 437 cells for cell type cS01 (Endo arterial)
# dimension of cell by gene count (437, 4618)
# [Log] 673 cells for cell type cS27 (CXCL14+ CAF)
# dimension of cell by gene count (673, 4618)
# [Log] 5421 cells for cell type cTNI17 (gd-like T)
# dimension of cell by gene count (5421, 4618)
# [Log] 1090 cells for cell type cM04 (DC2)
# dimension of cell by gene count (1090, 4618)
# [Log] 1008 cells for cell type Tumor cE10 (Tuft)
# dimension of cell by gene count (1008, 4618)
# [Log] 412 cells for cell type cS03 (Endo capillary)
# dimension of cell by gene count (412, 4618)
# [Log] 9530 cells for cell type cTNI08 (CD4+ Treg)
# dimension of cell by gene count (9530, 4618)
# [Log] 254 cells for cell type Tumor cE11 (Enteroendocrine)
# dimension of cell by gene count (254, 4618)
# [Log] 194 cells for cell type cS04 (Endo)
# dimension of cell by gene count (194, 4618)
# [Log] 660 cells for cell type cTNI21 (PLZF+ T prolif)
# dimension of cell by gene count (660, 4618)
# [Log] 216 cells for cell type cS26 (Myofibro)
# dimension of cell by gene count (216, 4618)
# [Log] 1871 cells for cell type cM10 (Granulocyte)
# dimension of cell by gene count (1871, 4618)
# [Log] 314 cells for cell type cE07 (Goblet/Enterocyte)
# dimension of cell by gene count (314, 4618)
# [Log] 38 cells for cell type cS14 (Endo)
# dimension of cell by gene count (38, 4618)
# [Log] 6182 cells for cell type cB3 (B CD40+ GC-like)
# dimension of cell by gene count (6182, 4618)
# [Log] 44 cells for cell type cS20 (Pericyte prolif)
# dimension of cell by gene count (44, 4618)
# [Log] 797 cells for cell type cTNI26 (ILC3)
# dimension of cell by gene count (797, 4618)
# [Log] 14 cells for cell type Tumor cE07 (Goblet/Enterocyte)
# dimension of cell by gene count (14, 4618)
# [Log] 6330 cells for cell type cTNI14 (CD8+ CXCL13+)
# dimension of cell by gene count (6330, 4618)
# [Log] 2920 cells for cell type Tumor cE06 (Immature Goblet)
# dimension of cell by gene count (2920, 4618)
# [Log] 217 cells for cell type cS23 (Fibro BMP-producing)
# dimension of cell by gene count (217, 4618)
# [Log] 1999 cells for cell type cTNI13 (CD8+ T IL17+)
# dimension of cell by gene count (1999, 4618)
# [Log] 194 cells for cell type cS11 (Endo proif)
# dimension of cell by gene count (194, 4618)
# [Log] 2095 cells for cell type cTNI07 (CD4+ CXCL13+)
# dimension of cell by gene count (2095, 4618)
# [Log] 439 cells for cell type cS25 (Fibro CCL8+)
# dimension of cell by gene count (439, 4618)
# [Log] 19434 cells for cell type cM02 (Macrophage-like)
# dimension of cell by gene count (19434, 4618)
# [Log] 93 cells for cell type cS07 (Endo capillary-like)
# dimension of cell by gene count (93, 4618)
# [Log] 361 cells for cell type cS29 (MMP3+ CAF)
# dimension of cell by gene count (361, 4618)
# [Log] 181 cells for cell type cS16 (Pericyte)
# dimension of cell by gene count (181, 4618)
# [Log] 1551 cells for cell type cM09 (mregDC)
# dimension of cell by gene count (1551, 4618)
# [Log] 497 cells for cell type cM06 (DC IL22RA2)
# dimension of cell by gene count (497, 4618)
# [Log] 2222 cells for cell type cE08 (Goblet)
# dimension of cell by gene count (2222, 4618)
# [Log] 717 cells for cell type cS09 (Endo)
# dimension of cell by gene count (717, 4618)
# [Log] 223 cells for cell type cS18 (Pericyte)
# dimension of cell by gene count (223, 4618)
# [Log] 2885 cells for cell type cTNI01 (CD4+ IL7R+)
# dimension of cell by gene count (2885, 4618)
# [Log] 639 cells for cell type cS28 (GREM1+ CAF)
# dimension of cell by gene count (639, 4618)
# [Log] 228 cells for cell type cS30 (CAF CCL8 Fibro-like)
# dimension of cell by gene count (228, 4618)
# [Log] 2255 cells for cell type cTNI16 (CD8+ CXCL13+ prolif)
# dimension of cell by gene count (2255, 4618)
# [Log] 20107 cells for cell type cP1 (Plasma IgA)
# dimension of cell by gene count (20107, 4618)
# [Log] 29726 cells for cell type Tumor cE03 (Stem/TA-like prolif)
# dimension of cell by gene count (29726, 4618)
# [Log] 5966 cells for cell type cTNI04 (CD4+ IL7R+CCL5+)
# dimension of cell by gene count (5966, 4618)
# [Log] 2832 cells for cell type cE06 (Immature Goblet)
# dimension of cell by gene count (2832, 4618)
# [Log] 1200 cells for cell type cS02 (Endo capillary)
# dimension of cell by gene count (1200, 4618)
# [Log] 383 cells for cell type cS24 (Fibro BMP-producing)
# dimension of cell by gene count (383, 4618)
# [Log] 473 cells for cell type Tumor cE08 (Goblet)
# dimension of cell by gene count (473, 4618)
# [Log] 4141 cells for cell type cE09 (Best4)
# dimension of cell by gene count (4141, 4618)
# [Log] 840 cells for cell type cM07 (pDC)
# dimension of cell by gene count (840, 4618)
# [Log] 1477 cells for cell type cTNI06 (CD4+ TFH)
# dimension of cell by gene count (1477, 4618)
# [Log] 2803 cells for cell type cTNI05 (CD4+ IL17+)
# dimension of cell by gene count (2803, 4618)
# [Log] 3325 cells for cell type cE03 (Stem/TA-like prolif)
# dimension of cell by gene count (3325, 4618)
# [Log] 457 cells for cell type cS31 (CAF stem niche Fibro-like)
# dimension of cell by gene count (457, 4618)
# [Log] 627 cells for cell type cS12 (Endo)
# dimension of cell by gene count (627, 4618)
# [Log] 3671 cells for cell type cMA01 (Mast)
# dimension of cell by gene count (3671, 4618)
# [Log] 254 cells for cell type cS33 (Schwann)
# dimension of cell by gene count (254, 4618)
# [Log] 1117 cells for cell type cTNI24 (NK GZMK+)
# dimension of cell by gene count (1117, 4618)
# [Log] 643 cells for cell type cTNI25 (NK XCL1+)
# dimension of cell by gene count (643, 4618)
# [Log] 2682 cells for cell type cTNI10 (CD8+ IL7R+)
# dimension of cell by gene count (2682, 4618)
# [Log] 936 cells for cell type cE10 (Tuft)
# dimension of cell by gene count (936, 4618)
# [Log] 252 cells for cell type cS15 (Pericyte)
# dimension of cell by gene count (252, 4618)
# [Log] 2708 cells for cell type cE02 (Stem/TA-like/Immature Goblet)
# dimension of cell by gene count (2708, 4618)
# [Log] 800 cells for cell type cS32 (Smooth Muscle)
# dimension of cell by gene count (800, 4618)
# [Log] 369 cells for cell type cTNI19 (gd-like T prolif)
# dimension of cell by gene count (369, 4618)
# [Log] 203 cells for cell type Tumor cE09 (Best4)
# dimension of cell by gene count (203, 4618)
# [Log] 688 cells for cell type cS22 (Fibro stem cell niche)
# dimension of cell by gene count (688, 4618)
# [Log] 3920 cells for cell type cTNI20 (PLZF+ T)
# dimension of cell by gene count (3920, 4618)
# [Log] 36490 cells for cell type Tumor cE01 (Stem/TA-like)
# dimension of cell by gene count (36490, 4618)
# [Log] 3878 cells for cell type cTNI15 (CD8+ CXCL13+ HSP+)
# dimension of cell by gene count (3878, 4618)
# [Log] 960 cells for cell type Tumor cE04 (Enterocyte 1)
# dimension of cell by gene count (960, 4618)
# [Log] 2003 cells for cell type cE04 (Enterocyte 1)
# dimension of cell by gene count (2003, 4618)
# [Log] 3178 cells for cell type cTNI18 (gd-like T PDCD1+)
# dimension of cell by gene count (3178, 4618)
# [Log] 6939 cells for cell type cB1 (B IGD+IgM+)
# dimension of cell by gene count (6939, 4618)
# [Log] 7886 cells for cell type cE01 (Stem/TA-like)
# dimension of cell by gene count (7886, 4618)
# [Log] 1051 cells for cell type cP3 (Plasma IgG prolif)
# dimension of cell by gene count (1051, 4618)

# %% [markdown]
# # Step 3: Save the gene expression lambdas

# %%
#outfile = '../gene_lambda_file.txt'
genemeanpd_markergs.to_csv(outfile,sep='\t')

# %%
genemeanpd_markergs
# Out:
#           cM03 (DC1)  cB2 (B GC-like)  cS05 (Endo venous)  cP2 (Plasma IgG)  \
# SAMD11      0.000002     1.354575e-07            0.000008      1.201868e-06
# HES4        0.000013     1.165777e-05            0.000024      4.646142e-06
# ISG15       0.000371     2.396111e-04            0.000769      1.925330e-04
# TNFRSF18    0.000006     8.850565e-06            0.000007      2.501304e-05
# TNFRSF4     0.000006     6.559940e-06            0.000058      1.902282e-05
# ...              ...              ...                 ...               ...
# ATP6AP1     0.000092     4.578629e-05            0.000107      3.338679e-05
# FAM50A      0.000057     6.297009e-05            0.000098      2.755123e-05
# LAGE3       0.000081     9.172346e-05            0.000126      4.414699e-05
# F8          0.000001     7.350558e-06            0.000035      6.585625e-07
# CLIC2       0.000162     6.653794e-07            0.000224      6.083002e-07
#
#           cTNI12 (CD8+ IL7R+)  cS10 (Endo tip cells)  cM08 (AS-DC)  \
# SAMD11           0.000000e+00           2.414196e-07      0.000004
# HES4             3.429627e-05           9.395580e-05      0.000052
# ISG15            2.311966e-04           4.572697e-04      0.000529
# TNFRSF18         1.415558e-04           1.726362e-05      0.000011
# TNFRSF4          3.706697e-05           9.563515e-04      0.000051
# ...                       ...                    ...           ...
# ATP6AP1          8.206867e-05           1.854192e-04      0.000216
# FAM50A           1.120739e-04           1.255818e-04      0.000125
# LAGE3            4.329798e-05           1.111914e-04      0.000143
# F8               2.725360e-06           6.688461e-06      0.000000
# CLIC2            5.775506e-07           6.426967e-05      0.000208
#
#           Tumor cE05 (Enterocyte 2)  cS21 (Fibro stem cell niche)  \
# SAMD11                 0.000000e+00                  1.471183e-05
# HES4                   1.226572e-04                  1.098259e-05
# ISG15                  4.971079e-04                  1.773285e-04
# TNFRSF18               2.664117e-06                  1.609288e-07
# TNFRSF4                2.876440e-06                  2.534074e-06
# ...                             ...                           ...
# ATP6AP1                8.972633e-05                  8.903323e-05
# FAM50A                 1.129033e-04                  1.115468e-04
# LAGE3                  2.785378e-05                  4.156548e-05
# F8                     3.451038e-08                  6.042331e-06
# CLIC2                  5.627824e-07                  7.764958e-05
#
#           cTNI22 (cTNI22)  ...  cS22 (Fibro stem cell niche)  \
# SAMD11           0.000000  ...                      0.000039
# HES4             0.000009  ...                      0.000016
# ISG15            0.000452  ...                      0.000202
# TNFRSF18         0.000084  ...                      0.000002
# TNFRSF4          0.000062  ...                      0.000002
# ...                   ...  ...                           ...
# ATP6AP1          0.000043  ...                      0.000094
# FAM50A           0.000110  ...                      0.000091
# LAGE3            0.000099  ...                      0.000049
# F8               0.000012  ...                      0.000004
# CLIC2            0.000001  ...                      0.000093
#
#           cTNI20 (PLZF+ T)  Tumor cE01 (Stem/TA-like)  \
# SAMD11        3.665324e-07               5.086971e-07
# HES4          9.994381e-05               6.711329e-05
# ISG15         6.084152e-04               6.048460e-04
# TNFRSF18      1.472609e-03               2.307296e-06
# TNFRSF4       5.529597e-05               2.146784e-06
# ...                    ...                        ...
# ATP6AP1       6.446808e-05               1.308182e-04
# FAM50A        1.541112e-04               1.449286e-04
# LAGE3         1.705586e-04               1.806062e-04
# F8            6.544941e-06               2.584643e-06
# CLIC2         1.473982e-07               1.790717e-06
#
#           cTNI15 (CD8+ CXCL13+ HSP+)  Tumor cE04 (Enterocyte 1)  \
# SAMD11                  0.000000e+00               0.000000e+00
# HES4                    1.021592e-05               1.102458e-04
# ISG15                   8.492946e-04               7.696574e-03
# TNFRSF18                5.548547e-04               5.822551e-07
# TNFRSF4                 1.335309e-04               2.988338e-06
# ...                              ...                        ...
# ATP6AP1                 8.931441e-05               1.345284e-04
# FAM50A                  1.354185e-04               9.213218e-05
# LAGE3                   8.740751e-05               3.099945e-05
# F8                      1.148462e-05               3.076564e-06
# CLIC2                   2.467462e-07               1.533624e-06
#
#           cE04 (Enterocyte 1)  cTNI18 (gd-like T PDCD1+)  cB1 (B IGD+IgM+)  \
# SAMD11           2.969258e-08               7.679331e-07      1.571570e-07
# HES4             4.320694e-05               1.901902e-05      9.532449e-06
# ISG15            6.667285e-03               7.051271e-04      2.246783e-04
# TNFRSF18         1.339242e-06               5.439643e-04      3.157481e-06
# TNFRSF4          1.819685e-07               3.784740e-05      2.829275e-06
# ...                       ...                        ...               ...
# ATP6AP1          7.459446e-05               5.469417e-05      4.041530e-05
# FAM50A           5.820652e-05               1.227087e-04      5.150738e-05
# LAGE3            1.530810e-05               1.374337e-04      8.629313e-05
# F8               2.969258e-08               1.202523e-05      8.105909e-07
# CLIC2            3.053337e-08               3.632715e-07      7.814851e-07
#
#           cE01 (Stem/TA-like)  cP3 (Plasma IgG prolif)
# SAMD11           9.711975e-07             4.587755e-07
# HES4             3.761882e-05             6.681818e-06
# ISG15            8.444898e-05             1.927991e-04
# TNFRSF18         1.783881e-06             2.542230e-05
# TNFRSF4          1.436634e-06             1.265869e-05
# ...                       ...                      ...
# ATP6AP1          8.255739e-05             5.271606e-05
# FAM50A           9.278696e-05             5.626052e-05
# LAGE3            1.143672e-04             1.138378e-04
# F8               2.945273e-06             1.505940e-06
# CLIC2            1.573451e-06             8.360396e-08
#
# [4618 rows x 98 columns]
